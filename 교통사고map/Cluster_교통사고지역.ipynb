# %%
import pandas as pd
import folium
df=pd.read_csv('도로교통공단_교통사고다발지역_20191010.csv',  encoding = 'euc-kr')
df.head()
# Out:
#    사고지역관리번호  사고년도  사고유형구분      위치코드      시도시군구명                    사고지역위치명  \
# 0   2013060  2012  스쿨존어린이  11110001  서울특별시 종로구1     서울특별시 종로구 혜화동(혜화초교 부근)
# 1   2013060  2012  스쿨존어린이  11290001  서울특별시 성북구1     서울특별시 성북구 종암동(숭례초교 부근)
# 2   2013060  2012  스쿨존어린이  11290002  서울특별시 성북구2  서울특별시 성북구 동소문동7가(정덕초교 부근)
# 3   2013060  2012  스쿨존어린이  11290003  서울특별시 성북구3     서울특별시 성북구 석관동(석관초교 부근)
# 4   2013060  2012  스쿨존어린이  11320001  서울특별시 도봉구1     서울특별시 도봉구 쌍문동(쌍문초교 부근)
#
#    발생건수  사상자수  사망자수  중상자수  경상자수  부상자수         위도          경도  \
# 0     2     2     0     1     1     0  37.588413  126.999607
# 1     2     2     0     0     1     1  37.595505  127.035733
# 2     2     2     0     2     0     0  37.597571  127.014564
# 3     3     3     0     2     1     0  37.610429  127.059596
# 4     2     2     0     0     2     0  37.648129  127.024430
#
#                                          사고다발지역폴리곤정보     데이터기준일자
# 0  {type:Polygon,coordinates:[[[127.002009,37.590...  2019-10-10
# 1  {type:Polygon,coordinates:[[[127.0381354,37.59...  2019-10-10
# 2  {type:Polygon,coordinates:[[[127.0169658,37.59...  2019-10-10
# 3  {type:Polygon,coordinates:[[[127.0619982,37.61...  2019-10-10
# 4  {type:Polygon,coordinates:[[[127.0268336,37.65...  2019-10-10

# %%
busan = df[df['사고지역위치명'].str.contains('부산')]

# %%
busan_location = busan[['사고지역위치명', '위도', '경도','사고유형구분']]
busan_location
# Out:
#                             사고지역위치명         위도          경도  사고유형구분
# 9             부산광역시 남구 용호동(용호초교 부근)  35.122549  129.109660  스쿨존어린이
# 10            부산광역시 남구 용호동(분포초교 부근)  35.128772  129.113662  스쿨존어린이
# 11          부산광역시 해운대구 반여동(장산초교 부근)  35.199556  129.119107  스쿨존어린이
# 12           부산광역시 금정구 남산동(남산초교 부근)  35.262775  129.088197  스쿨존어린이
# 68         부산광역시 중구 대청동1가(대청사거리 부근)  35.102976  129.027405   보행어린이
# ...                             ...        ...         ...     ...
# 10292  부산광역시 금정구 서동(부산은행 금사공단지점 부근)  35.214541  129.105527    무단횡단
# 10293     부산광역시 금정구 부곡동(부산정보관광고 부근)  35.222878  129.092748    무단횡단
# 10294      부산광역시 금정구 구서동(신동아아파트 부근)  35.257937  129.088586    무단횡단
# 10295      부산광역시 연제구 연산동(연산동우체국 부근)  35.174202  129.090526    무단횡단
# 10296      부산광역시 사상구 모라동(모라역교차로 부근)  35.188255  128.987979    무단횡단
#
# [760 rows x 4 columns]

# %%
from folium.plugins import MarkerCluster

map = folium.Map(location =  [35.1645702,129.0017602], zoom_start =12)

list1=[]
list2=[]
marker_cluster = MarkerCluster().add_to(map)
for a in busan_location.index:
    folium.Marker(location = [busan_location.loc[a,"위도"],busan_location.loc[a,"경도"]],
                  zoom_start=12,
                  popup=busan_location.loc[a,"사고유형구분"]).add_to(marker_cluster)
    list1.append(busan_location.loc[a,"위도"])
    list2.append(busan_location.loc[a,"경도"])
    
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map.save('cluster_accident.html')
